# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ----------
# absl-py                      1.4.0
# altgraph                     0.17.3
# anyio                        4.0.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# array-record                 0.4.0
# arrow                        1.2.3
# asttokens                    2.2.0
# astunparse                   1.6.3
# async-generator              1.10
# async-lru                    2.0.4
# attrs                        23.1.0
# Babel                        2.12.1
# backcall                     0.2.0
# beautifulsoup4               4.12.2
# bitstring                    4.0.2
# bleach                       6.0.0
# browser-cookie3              0.19.1
# bs4                          0.0.1
# build                        0.10.0
# cachetools                   5.3.0
# certifi                      2023.5.7
# cffi                         1.15.1
# charset-normalizer           3.1.0
# ...

# %%
# !pipenv install Scikit-Learn==1.3.1
# Out:
# Installing Scikit-Learn==1.3.1...
# Resolving Scikit-Learn==1.3.1...
# Added scikit-learn to Pipfile's [packages] ...
# Installation Succeeded
# Building requirements...
# Resolving dependencies...
# Success!
# Installing dependencies from Pipfile.lock (98d9d9)...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Creating a virtualenv for this project...
# Pipfile: C:\Users\ACER\OneDrive - Universitas Airlangga\Kuliah\Learn-MLZoomCamp2023\Learn-MLZoomCamp2023\HomeWork\Pipfile
# Using default python from C:\Users\ACER\AppData\Local\Programs\Python\Python311\python.exe (3.11.0) to create virtualenv...
# created virtual environment CPython3.11.0.final.0-64 in 1006ms
#   creator CPython3Windows(dest=C:\Users\ACER\.virtualenvs\HomeWork-pN6O2POM, clear=False, no_vcs_ignore=False, global=False)
# ...

# %%
# !pipenv install numpy flask
# Out:
# Installing numpy...
# Resolving numpy...
# Added numpy to Pipfile's [packages] ...
# Installation Succeeded
# Installing flask...
# Resolving flask...
# Added flask to Pipfile's [packages] ...
# Installation Succeeded
# Building requirements...
# Resolving dependencies...
# Success!
# Installing dependencies from Pipfile.lock (5443af)...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Pipfile.lock (98d9d9) out of date, updating to (5443af)...
# Locking [packages] dependencies...
# ...
# Locking [dev-packages] dependencies...
# Updated Pipfile.lock (a298bccc314a1c2b4ea14ff0de9cd1a99768396709860b66f9ce241c495443af)!

# %%
 pip install waitress
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
